# %% [markdown]
# Упражнение 1

# %%
import pandas as pd
df=pd.read_csv("mutant.txt",sep="	")
df.plot('Concentration, nM','Response', ylabel='Response',title='Mutant')
df1=pd.read_csv("wild_type.txt",sep="	")
df1.plot('Concentration, nM','Response', ylabel='Response',title='Wild type')
df2=pd.read_csv("Chromo.txt",sep="	")
df2.plot("Time (min)","Value (mAU)",ylabel="Value (mAU)",xlim=(4,7),title='Chromo')
# Out:
# <AxesSubplot:title={'center':'Chromo'}, xlabel='Time (min)', ylabel='Value (mAU)'>
